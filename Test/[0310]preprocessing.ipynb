# %%
from afmformats.formats.fmt_jpk import load_jpk
import afmformats
file_path = 'AFM images roughness/AFM images roughness/Cholecalciferol-2019.06.26-12.24.05.311.jpk-qi-image'
data = afmformats.load_data(file_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       2 import afmformats
#       3 file_path = 'AFM images roughness/AFM images roughness/Cholecalciferol-2019.06.26-12.24.05.311.jpk-qi-image'
# ----> 4 data = afmformats.load_data(file_path)
#
# File c:\Users\pmsda\anaconda3\envs\pycro_env\lib\site-packages\afmformats\formats\__init__.py:270, in load_data(path, meta_override, modality, data_classes_by_modality, diskcache, callback)
#     268         afmdata.append(ddi)
#     269 else:
# --> 270     raise ValueError("Unsupported file extension: '{}'!".format(path))
#     271 return afmdata
#
# ValueError: Unsupported file extension: 'AFM images roughness\AFM images roughness\Cholecalciferol-2019.06.26-12.24.05.311.jpk-qi-image'!

# %%
import pyfmreader
from pyfmreader.uff import UFF

# UFF는 input 받지 않는 class
uff_obj = UFF()
file_path = "AFM images roughness/AFM images roughness/Cholecalciferol-2019.06.26-12.24.05.311.jpk-qi-image"
qi_data = pyfmreader.loadJPKfile(file_path, uff_obj, "jpk-qi-image")
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[5], line 7
#       5 uff_obj = UFF()
#       6 file_path = "AFM images roughness/AFM images roughness/Cholecalciferol-2019.06.26-12.24.05.311.jpk-qi-image"
# ----> 7 qi_data = pyfmreader.loadJPKfile(file_path, uff_obj, "jpk-qi-image")
#
# File c:\Users\pmsda\anaconda3\envs\pycro_env\lib\site-packages\pyfmreader\jpk\loadjpkfile.py:20, in loadJPKfile(filepath, UFF, filesuffix)
#       8 """
#       9 Function used to load the metadata of a JPK file.
#      10
#    (...)
#      17                 UFF (uff.UFF): UFF object containing the loaded metadata.
#      18 """
#      19 with open(filepath, 'rb') as file:
# ---> 20     afm_file = ZipFile(file)
#      21     # Get global metadata stored in the files: header.properties and shared-data/header.properties
#      22     headercontents = afm_file.read('header.properties')
#
# File c:\Users\pmsda\anaconda3\envs\pycro_env\lib\zipfile.py:1268, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1266 try:
#    1267     if mode == 'r':
# -> 1268         self._RealGetContents()
#    1269     elif mode in ('w', 'x'):
#    1270         # set the modified flag so central directory gets written
#    1271         # even if no files are added to the archive
#    1272         self._didModify = True
#
# File c:\Users\pmsda\anaconda3\envs\pycro_env\lib\zipfile.py:1335, in ZipFile._RealGetContents(self)
#    1333     raise BadZipFile("File is not a zip file")
#    1334 if not endrec:
# -> 1335     raise BadZipFile("File is not a zip file")
#    1336 if self.debug > 1:
#    1337     print(endrec)
#
# BadZipFile: File is not a zip file

# %%
import zipfile

# zip file이 아니라 뜬다.  binary 형식인지 파악하기
file_path = "AFM images roughness/AFM images roughness/Cholecalciferol-2019.06.26-12.24.05.311.jpk-qi-image"
zipfile.is_zipfile(file_path)
# Out:
# False

# %%
with open(file_path, "rb") as f:
    data = f.read(5)
    print(data)
# Out:
# b'MM\x00*\x00'

# %%
from PIL import Image
img = Image.open(file_path)
print(img.format, img.size, img.mode)
# Out:
# TIFF (64, 64) P

# %%
# img.mode==P ->(8-bit pixels, mapped to any other mode using a color palette)
# 출처 : https://pillow.readthedocs.io/en/stable/handbook/concepts.html

import cv2
open_with_cv2 = cv2.imread(file_path,cv2.IMREAD_ANYDEPTH)
print(open_with_cv2.shape,open_with_cv2.dtype)
# Out:
# (64, 64) uint8

# %%
import numpy as np
img = Image.open(file_path)
open_with_pil = np.array(img)
print(open_with_pil.shape, open_with_pil.dtype)
# Out:
# (64, 64) uint8

# %%
# 둘이 다르다.
open_with_cv2 == open_with_pil
# Out:
# array([[ True,  True,  True, ..., False, False, False],
#        [ True,  True,  True, ..., False, False, False],
#        [ True,  True,  True, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
open_cv2_unchanged = cv2.imread(file_path,cv2.IMREAD_UNCHANGED)
print(open_cv2_unchanged.shape,open_cv2_unchanged.dtype)
# Out:
# (64, 64, 3) uint8

# %%
converted_img = img.convert('RGB')

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots(1,4,figsize = (12,3))
ax[0].imshow(img)
ax[1].imshow(open_with_cv2)
ax[2].imshow(open_with_pil)
ax[3].imshow(converted_img)

# %%
# 주어진 폴더 내에 jpk-qu-image만 불러오기
import glob
folder_path = "AFM images roughness/AFM images roughness/"
file_pattern = folder_path + "Cholecalciferol-*.jpk-qi-image"
image_files = glob.glob(file_pattern)
image_files
# Out:
# ['AFM images roughness/AFM images roughness\\Cholecalciferol-2019.06.26-12.24.05.311.jpk-qi-image',
#  'AFM images roughness/AFM images roughness\\Cholecalciferol-2019.06.26-12.39.19.020.jpk-qi-image',
#  'AFM images roughness/AFM images roughness\\Cholecalciferol-2019.06.26-12.49.18.752.jpk-qi-image',
#  'AFM images roughness/AFM images roughness\\Cholecalciferol-2019.06.26-13.38.48.864.jpk-qi-image',
#  'AFM images roughness/AFM images roughness\\Cholecalciferol-2019.06.26-14.02.30.932.jpk-qi-image',
#  'AFM images roughness/AFM images roughness\\Cholecalciferol-2019.06.26-14.12.44.535.jpk-qi-image']

# %%
from PIL import Image

fig, ax = plt.subplots(1,len(image_files),figsize = (3*len(image_files),3))
for idx,img in enumerate(image_files):
    i = Image.open(img)
    i = i.convert('RGB')
    ax[idx].imshow(i)

# %%
import pyfmreader

# 파일 경로
file_path = "AFM Data/BARLKD1PERP/BARLKD1-1-data-HS-CAL-Extend-YM/LKD1-1-data-2018.07.19-10.37.27.631_processed-2019.01.25-13.56.28.jpk-proc-force"

# UFF 객체 생성
uff = pyfmreader.uff.UFF()

# JPK 파일 로드
jpk_data = pyfmreader.loadJPKfile(file_path, uff, "jpk-proc-force")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 10
#       7 uff = pyfmreader.uff.UFF()
#       9 # JPK 파일 로드
# ---> 10 jpk_data = pyfmreader.loadJPKfile(file_path, uff, "jpk-proc-force")
#
# File c:\Users\pmsda\anaconda3\envs\pycro_env\lib\site-packages\pyfmreader\jpk\loadjpkfile.py:26, in loadJPKfile(filepath, UFF, filesuffix)
#      23 header_properties_raw = bytes(headercontents).decode().splitlines()
#      24 header_properties = {item.split("=")[0]:item.split("=")[1] for item in header_properties_raw if not item.startswith("#")}
# ---> 26 sharedheadercontents = afm_file.read('shared-data/header.properties')
#      27 shared_data_properties_raw = bytes(sharedheadercontents).decode().splitlines()
#      28 UFF._sharedataprops = {item.split("=")[0]:item.split("=")[1] for item in shared_data_properties_raw if not item.startswith("#")}
#
# File c:\Users\pmsda\anaconda3\envs\pycro_env\lib\zipfile.py:1480, in ZipFile.read(self, name, pwd)
#    1478 def read(self, name, pwd=None):
#    1479     """Return file bytes for name."""
# -> 1480     with self.open(name, "r", pwd) as fp:
#    1481         return fp.read()
#
# File c:\Users\pmsda\anaconda3\envs\pycro_env\lib\zipfile.py:1519, in ZipFile.open(self, name, mode, pwd, force_zip64)
#    1516     zinfo._compresslevel = self.compresslevel
#    1517 else:
#    1518     # Get info object for name
# -> 1519     zinfo = self.getinfo(name)
#    1521 if mode == 'w':
#    1522     return self._open_to_write(zinfo, force_zip64=force_zip64)
#
# File c:\Users\pmsda\anaconda3\envs\pycro_env\lib\zipfile.py:1446, in ZipFile.getinfo(self, name)
#    1444 info = self.NameToInfo.get(name)
#    1445 if info is None:
# -> 1446     raise KeyError(
#    1447         'There is no item named %r in the archive' % name)
#    1449 return info
#
# KeyError: "There is no item named 'shared-data/header.properties' in the archive"

# %%
# 이러한 형식이어야만 열린다. 'shared-data/header.properties' 원래 이러한 형식으로 데이터가 저장되는지 모르겠다.
import zipfile
f = zipfile.ZipFile(file_path)
f.namelist()
# Out:
# ['header.properties']

# %%
# 다른 방법으로 열어보기
import jpkfile
file = jpkfile.JPKFile(file_path)
file.segments
# Out:
# {}

# %%
# module example 보면 다른 결과가 나오는데 원래 이러한 데이터인지 파악을 못하겠다.
file.get_info('segments')
# Out:
# '======================================================================\nSEGMENT\tTYPE\tNUM POINTS\tDURATION\n-------\t----\t----------\t--------\n======================================================================\n'
